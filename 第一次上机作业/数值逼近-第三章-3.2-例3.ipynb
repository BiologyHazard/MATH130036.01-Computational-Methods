# %%
import matplotlib.pyplot as plt
import numpy as np

from interpolation import make_cubic_spline_interpolation

# %%
x = np.array([0.00, 1.50, 2.00, 3.00, 4.50, 5.45, 6.00, 7.50, 9.00, 9.80, 10.50, 12.00, 13.38, 14.48])
y = np.array([0.28, 1.75, 2.00, 3.43, 3.29, 4.00, 4.48, 6.00, 7.37, 8.00, 8.48, 9.27, 9.68, 9.89])
s = make_cubic_spline_interpolation(x, y)

plt.grid()
plt.plot(x, y, 'x', label='nodes')
x = np.linspace(x[0], x[-1], 1000+1)
plt.plot(x, s(x), label='cubic spline (natural)')
plt.legend()
plt.show()
